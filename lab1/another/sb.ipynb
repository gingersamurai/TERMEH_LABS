# %%
from sympy import expand, factor, symbols
x, y = symbols('x y')
expr = x + 2*y
expanded_expr = expand(x*expr)
expanded_expr
x**2 + 2*x*y
factor(expanded_expr)
x*(x + 2*y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/gingersamurai/coding/MAI/TERMEH_LABS/lab1/sb.ipynb Cell 1' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/gingersamurai/coding/MAI/TERMEH_LABS/lab1/sb.ipynb#ch0000000?line=0'>1</a> from sympy import expand, factor
# ----> <a href='vscode-notebook-cell:/home/gingersamurai/coding/MAI/TERMEH_LABS/lab1/sb.ipynb#ch0000000?line=1'>2</a> expanded_expr = expand(x*expr)
#       <a href='vscode-notebook-cell:/home/gingersamurai/coding/MAI/TERMEH_LABS/lab1/sb.ipynb#ch0000000?line=2'>3</a> expanded_expr
#       <a href='vscode-notebook-cell:/home/gingersamurai/coding/MAI/TERMEH_LABS/lab1/sb.ipynb#ch0000000?line=3'>4</a> x**2 + 2*x*y
#
# NameError: name 'x' is not defined

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2 * np.pi * t)
line, = ax.plot(t, s, lw=2)

ax.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05))

# ax.set_ylim(-2, 2);
